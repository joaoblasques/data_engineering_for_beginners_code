# %%
# %%sql
# use prod_db
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Run SQL queries as shown below

# %%
# %%sql
# show tables
# Out:
#   namespace tableName  isTemporary
# 0   prod_db    orders        False
# 1   prod_db  partsupp        False
# 2   prod_db  supplier        False
# 3   prod_db    nation        False
# 4   prod_db  lineitem        False
# 5   prod_db      part        False
# 6   prod_db  customer        False
# 7   prod_db    region        False

# %%
# %%sql --show
# select 1
# Out:
#    1
# 0  1

# %% [markdown]
# Run Python code as shown below

# %%
print(f'This is Python')
# Out:
# This is Python
